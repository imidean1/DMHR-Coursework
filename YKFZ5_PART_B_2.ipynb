# %% [markdown]
# # Assignment B
#
# GITHUB:https://github.com/imidean1/DMHR-Coursework
#
# first we load all our datasets

# %%
import pandasql as psql
import numpy as np 
import pandas as pd 
import matplotlib as mp
import os as os
os.chdir("/Users/dingo/desktop")
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  /Users/dingo/Desktop

# %%
#Importing Datasets

country_codes= pd.read_csv("country_codes.csv",skipinitialspace=True)

display(country_codes.head(5))
# Out:
#    country          name
# 0     1010       Algeria
# 1     1020        Angola
# 2     1025         Benin
# 3     1030      Botswana
# 4     1035  Burkina Faso

# %%
population= pd.read_csv("pop.csv",skipinitialspace=True)

display(population.head(5))
# Out:
#    Country  Admin1 SubDiv  Year  Sex  Frmat       Pop1      Pop2      Pop3  \
# 0     1060     NaN    NaN  1980    1      7   137100.0    3400.0   15800.0
# 1     1060     NaN    NaN  1980    2      7   159000.0    4000.0   18400.0
# 2     1125     NaN    NaN  1955    1      2  5051500.0  150300.0  543400.0
# 3     1125     NaN    NaN  1955    2      2  5049400.0  145200.0  551000.0
# 4     1125     NaN    NaN  1956    1      2  5353700.0  158700.0  576600.0
#
#    Pop4  ...     Pop18    Pop19    Pop20    Pop21    Pop22    Pop23  Pop24  \
# 0   NaN  ...       NaN   5300.0      NaN   2900.0      NaN      NaN    NaN
# 1   NaN  ...       NaN   6200.0      NaN   3400.0      NaN      NaN    NaN
# 2   NaN  ...  110200.0  51100.0  41600.0  14300.0  11800.0  25300.0    NaN
# 3   NaN  ...  122100.0  51100.0  50700.0  15800.0  18000.0  28500.0    NaN
# 4   NaN  ...  116900.0  54100.0  44000.0  14900.0  12400.0  26600.0    NaN
#
#    Pop25   Pop26        Lb
# 0    NaN  6500.0    5000.0
# 1    NaN  7500.0    6000.0
# 2    NaN     0.0  253329.0
# 3    NaN     0.0  237901.0
# 4    NaN     0.0  250022.0
#
# [5 rows x 33 columns]

# %%
death1= pd.read_csv("Morticd10_part1.csv",skipinitialspace=True)

display(death1.head(5))
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Country  Admin1  SubDiv  Year List Cause  Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1400     NaN     NaN  2001  101  1000    1      7         8      332
# 1     1400     NaN     NaN  2001  101  1000    2      7         8      222
# 2     1400     NaN     NaN  2001  101  1001    1      7         8       24
# 3     1400     NaN     NaN  2001  101  1001    2      7         8       14
# 4     1400     NaN     NaN  2001  101  1002    1      7         8        0
#
#    ...  Deaths21  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  \
# 0  ...      95.0       NaN       NaN       NaN       NaN       0.0
# 1  ...     112.0       NaN       NaN       NaN       NaN       0.0
# 2  ...       5.0       NaN       NaN       NaN       NaN       0.0
# 3  ...       6.0       NaN       NaN       NaN       NaN       0.0
# 4  ...       0.0       NaN       NaN       NaN       NaN       0.0
#
#    IM_Deaths1  IM_Deaths2  IM_Deaths3  IM_Deaths4
# 0         8.0         NaN         NaN         NaN
# 1        11.0         NaN         NaN         NaN
# 2         0.0         NaN         NaN         NaN
# 3         0.0         NaN         NaN         NaN
# 4         0.0         NaN         NaN         NaN
#
# [5 rows x 39 columns]

# %%
death2= pd.read_csv("Morticd10_part2.csv",skipinitialspace=True)

display(death2.head(5))
# Out:
#    Country  Admin1 SubDiv  Year List Cause  Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1400     NaN    NaN  2005  101  1000    1      7         8      386
# 1     1400     NaN    NaN  2005  101  1000    2      7         8      287
# 2     1400     NaN    NaN  2005  101  1001    1      7         8       29
# 3     1400     NaN    NaN  2005  101  1001    2      7         8       21
# 4     1400     NaN    NaN  2005  101  1002    1      7         8        0
#
#    ...  Deaths21  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  \
# 0  ...     136.0       NaN       NaN       NaN       NaN       0.0
# 1  ...     163.0       NaN       NaN       NaN       NaN       0.0
# 2  ...      13.0       NaN       NaN       NaN       NaN       0.0
# 3  ...      16.0       NaN       NaN       NaN       NaN       0.0
# 4  ...       0.0       NaN       NaN       NaN       NaN       0.0
#
#    IM_Deaths1  IM_Deaths2  IM_Deaths3  IM_Deaths4
# 0        10.0         NaN         NaN         NaN
# 1         6.0         NaN         NaN         NaN
# 2         0.0         NaN         NaN         NaN
# 3         0.0         NaN         NaN         NaN
# 4         0.0         NaN         NaN         NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## question 1:
# What was the population and the total number of deaths (from all causes, all ages) in 2010 for:
# o Iceland
# o Italy
# o New Zealand
#
# Total number of population for each country for 2010 is shown below

# %%
# First we calculate total population of each country 
from pandasql import PandaSQL
pdsql = PandaSQL()
temp = pdsql('select Country, sum(Pop1) as total_population from population where Country in ("4290","4180","5150","5020") and Year="2010" group by 1 ;')
total_populations=pdsql('select b.name, a.* from temp a left outer join country_codes b on a.Country = b.country;')
display(total_populations)
# Out:
#           name  Country  total_population
# 0        Italy     4180        60483386.0
# 1       Sweden     4290         9378126.0
# 2    Australia     5020        22297515.0
# 3  New Zealand     5150         4367360.0

# %% [markdown]
# total number of deaths forr all causes and all ages during 2010 for each country is

# %%
# getting total deaths for each country 

total_death=pdsql("select Country, sum(Deaths1) as total_deaths from death2 where country in('4180','4290','5150') and Year ='2010' group by 1;")
total_population_death = pdsql("select a.*, b.total_deaths from total_populations a left outer join total_death b on a.Country = b.Country;")
display(total_population_death)
# Out:
#           name  Country  total_population  total_deaths
# 0        Italy     4180        60483386.0     1169230.0
# 1       Sweden     4290         9378126.0      181038.0
# 2    Australia     5020        22297515.0           NaN
# 3  New Zealand     5150         4367360.0       57298.0

# %% [markdown]
# ## Question 2. What was the distribution of deaths (all causes, all years) by age group in Italy?
# o Visualise the results using a histogram.

# %%
# We will take the Year and Death 1 columns for both datasets, union all then histogram

italy1 = pdsql('select Year, Deaths1 ,Cause from death1 where country= "4180";')
italy2 = pdsql('select Year, Deaths1, Cause from death2 where country= "4180";')

# %%
italy_dath = pdsql('select * from italy1 UNION ALL select * from italy2 order by Year desc;')

# %%
italy_death = pdsql('select sum(Deaths1) as total_death,  Year from italy_dath group by 2;')
display(italy_death)
# Out:
#     total_death  Year
# 0       1177794  2003
# 1       1090102  2004
# 2       1136656  2005
# 3       1117228  2006
# 4       1145762  2007
# 5       1162940  2008
# 6       1176876  2009
# 7       1169230  2010
# 8       1188306  2011
# 9       1227040  2012
# 10      1199396  2013
# 11      1197340  2014
# 12      1292096  2015

# %%
from matplotlib import pyplot
mp.pyplot.bar( italy_death['Year'], height=italy_death['total_death'])
# Out:
# <BarContainer object of 13 artists>

# %% [markdown]
# ## Question 3: What were the top five causes of death (top five ICD-10 terms) in Italy across all years for the Neoplasm ICD10-category (C00-D48)?
#
# a Generate a table with the cause of death, the number of deaths, and the proportion of overall deaths.

# %%
italy_death2 = pdsql('select Cause, sum(Deaths1) as total_death, Year from italy_dath group by 1,3;')

# %%
neoplasem_deaths_italy = pdsql('select Year, Cause, total_death as Neoplasem_death from italy_death2 where Cause like "C%" or Cause like "DO%" or Cause like "D1%" or Cause like "D2%" or Cause like "D3%" or Cause like "D4%" or Cause like "D41%" or Cause like "D42%" or Cause like "D43%" or Cause like "D44%" or Cause like "D45%" or Cause like "D46%" or Cause like "D47%" or Cause like "D48%" group by 1, 2  order by 3 desc;')

# %%
# generate a table showing the proportion of deaths due to neoplasem by year 

deahts_proportion_neoplasem = pdsql('select a.*, b.total_death from neoplasem_deaths_italy a left outer join italy_death b on a.year = b.year order by Year ; ')

# %%
deahts_proportion_neoplasem['proportion_neoplasem_death']= deahts_proportion_neoplasem['Neoplasem_death']/deahts_proportion_neoplasem['total_death']
deahts_proportion_neoplasem['percentage_deaths_due_to_cancer'] = deahts_proportion_neoplasem['proportion_neoplasem_death'] * 100

display(deahts_proportion_neoplasem.head(5))
# Out:
#    Year Cause  Neoplasem_death  total_death  proportion_neoplasem_death  \
# 0  2003  C349            31925      1177794                    0.027106
# 1  2003  C509            11566      1177794                    0.009820
# 2  2003  C169            10555      1177794                    0.008962
# 3  2003  C189             9706      1177794                    0.008241
# 4  2003  C259             7832      1177794                    0.006650
#
#    percentage_deaths_due_to_cancer
# 0                         2.710576
# 1                         0.982005
# 2                         0.896167
# 3                         0.824083
# 4                         0.664972

# %% [markdown]
# The top 5 neoplasems that casuded death in italy over all years were

# %%
top_5_neoplasems =pdsql('select distinct (Cause) as Cause, sum(Neoplasem_death) as death from deahts_proportion_neoplasem group by 1 order by 2 desc;')
display(top_5_neoplasems.head(5))

# C349 = Malignant neoplasm of unspecified part of bronchus or lung
# C509 = Malignant neoplasm of breast of unspecified site.
# C189 = Malignant neoplasm of colon
# C169 = Malignant neoplasm of stomach
# C259 = Malignant neoplasm of pancreas
# Out:
#   Cause   death
# 0  C349  426451
# 1  C509  155895
# 2  C189  143188
# 3  C169  125679
# 4  C259  120070

# %% [markdown]
# 3b  Generate a pie chart to visualize the proportion of deaths.
#
# I will present a pie chart showing cancer deaths as a proportiin of all deaths

# %%
#Lets sum total cancer deaths by year 
cancer_prop_all = pdsql('select distinct(Year) as Year, sum(Neoplasem_death) as cancer_death, total_death from deahts_proportion_neoplasem group by 1 order by 1 ;' )

# %%
#now we caclualte proportion and percentage 

cancer_prop_all['proportion_cancer_death']= cancer_prop_all['cancer_death']/cancer_prop_all['total_death']
cancer_prop_all['percentage_cancer_death'] = cancer_prop_all['proportion_cancer_death'] * 100

display(cancer_prop_all)
# Out:
#     Year  cancer_death  total_death  proportion_cancer_death  \
# 0   2003        167140      1177794                 0.141909
# 1   2004        166439      1090102                 0.152682
# 2   2005        166542      1136656                 0.146519
# 3   2006        168662      1117228                 0.150965
# 4   2007        171623      1145762                 0.149789
# 5   2008        172781      1162940                 0.148573
# 6   2009        174677      1176876                 0.148424
# 7   2010        175044      1169230                 0.149709
# 8   2011        175972      1188306                 0.148086
# 9   2012        177348      1227040                 0.144533
# 10  2013        176219      1199396                 0.146923
# 11  2014        177302      1197340                 0.148080
# 12  2015        178879      1292096                 0.138441
#
#     percentage_cancer_death
# 0                 14.190937
# 1                 15.268204
# 2                 14.651926
# 3                 15.096471
# 4                 14.978940
# 5                 14.857258
# 6                 14.842430
# 7                 14.970878
# 8                 14.808644
# 9                 14.453319
# 10                14.692312
# 11                14.807991
# 12                13.844095

# %%
#Now we create pie charts
import matplotlib.pyplot as plt

# Plot
plt.pie(cancer_prop_all['percentage_cancer_death'], labels=cancer_prop_all['Year'],startangle=90)
plt.show()

# %% [markdown]
# ## Question 4. Are there differences by age group for deaths from Neoplasms (C00-D48) in Australia for 2010? Identify the top five age groups in Australia dying with a Neoplasms cause of death.

# %%
##Create a dataset of all deaths due to cancer 
aust = pdsql('select Cause, Frmat as age_grp, sum(Deaths1) as deaths from death2 where Country = "5020" and Year= "2010" and  Cause like "C%" or Cause like "DO%" or Cause like "D1%" or Cause like "D2%" or Cause like "D3%" or Cause like "D4%" or Cause like "D41%" or Cause like "D42%" or Cause like "D43%" or Cause like "D44%" or Cause like "D45%" or Cause like "D46%" or Cause like "D47%" or Cause like "D48%" group by 1, 2 order by 3 desc;')

# %%
## age_grp 0 is death for all ages so we will not select it 
aust_drop_0 = pdsql('select * from aust where age_grp in("1","2","3","4","5","6","7","8","9");')

# %%
## findng which age group suffered the most death from cancer in 2010 
aust_age_death =pdsql('select age_grp as age_group, sum(deaths) as deaths from aust_drop_0 group by 1 order by 2 desc')

# %% [markdown]
# The below table shows the distribution of deaths due to neoplasems by age group.
# A cursory examination appears to indicate a difference in deaths by age group however, it is worth noting that coding of age groups is rather broad meaning that it is rather difficult to compare standardized mortality rates between groups.

# %%
display(aust_age_death.head(5))
# Out:
#    age_group  deaths
# 0          1   26496
# 1          2   24364
# 2          4     896
# 3          3      37
# 4          6       2

# %% [markdown]
# ### Q5 Compare and contrast the frequency of deaths by Neoplasms in Italy and Australia in 2010.

# %%
## Lets calculate number of deaths in Aus 2010

# %%
temp_2 = pdsql('select Country, sum(Pop1) as total_population from population where Country = "5020" and Year="2010" group by 1 ;')
total_populations_aus=pdsql('select b.name, a.* from temp a left outer join country_codes b on a.Country = b.country;')
display(total_populations_aus)
# Out:
#           name  Country  total_population
# 0        Italy     4180        60483386.0
# 1       Sweden     4290         9378126.0
# 2    Australia     5020        22297515.0
# 3  New Zealand     5150         4367360.0

# %%
aus_1 = pdsql('select Year, Deaths1 ,Cause from death1 where country= "5020" ;')
aus_2 = pdsql('select Year, Deaths1, Cause from death2 where country= "5020" ')
aus_dath = pdsql('select * from aus_1 UNION ALL select * from aus_2 order by Year desc;')
aus_death = pdsql('select sum(Deaths1) as total_death,  Year from aus_dath group by 2;')

# %%
aus_death2 = pdsql('select Cause, sum(Deaths1) as total_death, Year from aus_dath group by 1,3;')

# %%
neoplasem_deaths_aus = pdsql('select Year, Cause, total_death as Neoplasem_death from aus_death2 where Cause like "C%" or Cause like "DO%" or Cause like "D1%" or Cause like "D2%" or Cause like "D3%" or Cause like "D4%" or Cause like "D41%" or Cause like "D42%" or Cause like "D43%" or Cause like "D44%" or Cause like "D45%" or Cause like "D46%" or Cause like "D47%" or Cause like "D48%" group by 1, 2  order by 3 desc;')

# %%
# generate a table showing the proportion of deaths due to neoplasem by year 

deahts_proportion_neoplasem_aus = pdsql('select a.*, b.total_death from neoplasem_deaths_aus a left outer join aus_death b on a.year = b.year order by Year ; ')

display(deahts_proportion_neoplasem_aus)
# Out:
#       Year Cause  Neoplasem_death  total_death
# 0     1998  C349             6386       254716
# 1     1998   C61             2570       254716
# 2     1998  C509             2524       254716
# 3     1998  C189             2418       254716
# 4     1998   C80             2123       254716
# 5     1998  C259             1393       254716
# 6     1998  C859             1190       254716
# 7     1998  C169             1086       254716
# 8     1998   C20              975       254716
# 9     1998  C159              949       254716
# 10    1998  C439              823       254716
# 11    1998  C679              793       254716
# 12    1998   C64              771       254716
# 13    1998   C56              749       254716
# 14    1998  C900              605       254716
# 15    1998  C719              582       254716
# 16    1998  C920              569       254716
# 17    1998  C187              370       254716
# 18    1998   C97              361       254716
# 19    1998  C220              308       254716
# 20    1998  C180              263       254716
# 21    1998  C539              258       254716
# 22    1998  D469              253       254716
# 23    1998  C911              245       254716
# 24    1998   C19              230       254716
# 25    1998  C341              220       254716
# 26    1998  C450              213       254716
# 27    1998  C250              210       254716
# 28    1998  C260              208       254716
# 29    1998  C221              204       254716
# ...    ...   ...              ...          ...
# 6266  2016  C942                1       317008
# 6267  2016  C944                1       317008
# 6268  2016  C946                1       317008
# 6269  2016  C947                1       317008
# 6270  2016  C957                1       317008
# 6271  2016  C962                1       317008
# 6272  2016  C966                1       317008
# 6273  2016  C968                1       317008
# 6274  2016  D110                1       317008
# 6275  2016  D126                1       317008
# 6276  2016  D130                1       317008
# 6277  2016  D134                1       317008
# 6278  2016  D137                1       317008
# 6279  2016  D164                1       317008
# 6280  2016  D179                1       317008
# 6281  2016  D219                1       317008
# 6282  2016  D239                1       317008
# 6283  2016  D321                1       317008
# 6284  2016  D330                1       317008
# 6285  2016  D331                1       317008
# 6286  2016   D34                1       317008
# 6287  2016  D382                1       317008
# 6288  2016  D412                1       317008
# 6289  2016  D441                1       317008
# 6290  2016  D445                1       317008
# 6291  2016  D467                1       317008
# 6292  2016  D470                1       317008
# 6293  2016  D477                1       317008
# 6294  2016  D484                1       317008
# 6295  2016  D486                1       317008
#
# [6296 rows x 4 columns]

# %%
cancer_prop_aus = pdsql('select distinct(Year) as Year, sum(Neoplasem_death) as cancer_death, total_death from deahts_proportion_neoplasem_aus group by 1 order by 1 ;' )

# %%
cancer_prop_aus['proportion_cancer_death']= cancer_prop_aus['cancer_death']/cancer_prop_aus['total_death']
cancer_prop_aus['percentage_cancer_death'] = cancer_prop_aus['proportion_cancer_death'] * 100

display(cancer_prop_aus)
# Out:
#     Year  cancer_death  total_death  proportion_cancer_death  \
# 0   1998         35673       254716                 0.140050
# 1   1999         35879       256158                 0.140066
# 2   2000         36564       257568                 0.141959
# 3   2001         37459       257314                 0.145577
# 4   2002         38268       266094                 0.143814
# 5   2003         38266       263568                 0.145185
# 6   2004         38883       264628                 0.146935
# 7   2006         39763       267478                 0.148659
# 8   2007         40330       275708                 0.146278
# 9   2008         42422       287892                 0.147354
# 10  2009         41962       281520                 0.149055
# 11  2010         43316       286946                 0.150955
# 12  2011         43737       293864                 0.148834
# 13  2012         43509       294196                 0.147891
# 14  2013         44676       295356                 0.151262
# 15  2014         44740       307160                 0.145657
# 16  2015         46573       318104                 0.146408
# 17  2016         46307       317008                 0.146075
#
#     percentage_cancer_death
# 0                 14.005010
# 1                 14.006590
# 2                 14.195863
# 3                 14.557700
# 4                 14.381384
# 5                 14.518454
# 6                 14.693456
# 7                 14.865896
# 8                 14.627795
# 9                 14.735387
# 10                14.905513
# 11                15.095523
# 12                14.883415
# 13                14.789120
# 14                15.126153
# 15                14.565699
# 16                14.640809
# 17                14.607518

# %%
cancer_aus_2010 = pdsql('select * from cancer_prop_aus where Year = "2010"  ;' )

# %%
## The proportion of deaths attributed to cancer in australia during 2010 is:

# %%
display(cancer_aus_2010)
# Out:
#    Year  cancer_death  total_death  proportion_cancer_death  \
# 0  2010         43316       286946                 0.150955
#
#    percentage_cancer_death
# 0                15.095523

# %%
# The proportion of deaths attributed to cancer during 2010 in italy is:

# %%
cancer_italy_2010 = pdsql('select * from cancer_prop_all where Year = "2010"  ;' )

# %%
display(cancer_italy_2010)
# Out:
#    Year  cancer_death  total_death  proportion_cancer_death  \
# 0  2010        175044      1169230                 0.149709
#
#    percentage_cancer_death
# 0                14.970878

# %% [markdown]
# # Analysis

# %% [markdown]
# #### As we can see the proportion of cancer deaths there is little evidence to suggest a difference on the whole between Australia and Italy.
# #### This is an expected result as both countries are developed and we would assume that they have relatively similar treatments available  and demographic profiles.
# #### That said, a closer examination of the distribution of cancers by ICD codes show that Australia has a higher fraction of deaths related to the skin cancer group
# #### in comparison to Australia. We also notice higher incidence of gastric cancers in Australia as well. Taking into consideration lifestyle factors in Australia versus Italy, these results are also not surprising.
# #### These same results and trends are validated when checking the projections from the global burden of disease study.
